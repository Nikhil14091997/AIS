# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
import time
import urllib3

def date_format(str1):
    '''
    l[0] = Month
    l[1] = Date
    l[2] = Year
    '''
    str1 = str1.lower()
    l1 = str1.replace(',','').split(' ')
    # December -> dec
    if (len(l1[0]) > 3):
        l1[0] = l1[0][:3]
    dict1 = {'jan' : 1,
        'feb':2,
        'mar':3,
        'apr':4,
        'may':5,
        'jun':6,
        'jul':7,
        'aug':8,
        'sep':9,
        'oct':10,
        'nov':11,
        'dec':12
    }
    a = str(dict1[l1[0]])
    return str(l1[1]+'-'+ a +'-'+str(l1[2]))

# added new Keywords
keywords = [
    "medical devices",
    "medcial device",
    "implantable",
    "software as medical device",
    "samd",
    "mdufa",
    "combination product",
    "combination products",
    "guidance",
    "notified bodies",
    "notified body",
    "artificial intelligence mdeical devices",
    "artificial intelligence mdeical device",
    "artificial intelligence/machine learning-enabled medical devices"
    "artificial intelligence/machine learning-enabled medical device",
    "classification",
    "designation",
    "approval",
    "recall",
    "medicinal products",
    "diagnostic",
    "diagnosis",
    "cov19",
    "c-19",
    "covid-19",
    "covid 19",
    "patient",
    "patients",
    "bone",
    "bones",
    "oximetry","cerebral","somatic",
    "balancebelt","biotechnology","medical's","muscles","muscel", "regulatory"
    
]

def check_keywords_in_title(title, keywords):
    match = []
    for word in keywords:
        if word in title:
            match.append(word)
    return match
class Content:
    def __init__(self, url, title, date):
        self.url = url
        self.title = title
        self.date = date
   
def getPage(url):
    req = requests.get(url)
    return BeautifulSoup(req.text, 'html.parser')

# https://www.mddionline.com/regulatory-quality/regulations
def scrape_mddionline(url):
    cookie_jar=requests.cookies.RequestsCookieJar()
    session=requests.Session()
    header = {'Accept-Encoding': 'gzip, deflate', 'Accept': '/', 'Connection': 'keep-alive',
     "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0"
     }
    print("Utility function for https://www.mddionline.com/regulatory-quality/regulations called !")
    bs = getPage(url)
    print("getPage function for https://www.mddionline.com/regulatory-quality/regulations called !")
    all_news=[]
    table = bs.find_all('article', attrs={'class':'article-teaser article-teaser__icon__article article-teaser__aside'})
    for row in table:
        title = row.find('a').text.lower()
        print("\t Checking for title: ", title)
        url_content = row.find('a')['href']
        date = date_format(row.find('span').text.lstrip().rstrip())
        news = {}
        news['identifier'], news['title'], news['url'], news['date'], news['keywords'], news['content'] =url, title, url_content, date, '', ''
        ret = check_keywords_in_title(title, keywords)
        if ret:
            match = " "
            match = " | ".join(word for word in ret)
            print("\t Found a keyword!!")
            url_inner = 'https://www.mddionline.com' + url_content
            print(url_content)
            print("Keyword foud at:-", url_inner)
            bs_inner = getPage(url_inner)
            content_inner = bs_inner.find('div', {'itemprop':'articleBody'})
#             print(content_inner.text)
            news['content'] = content_inner.text.lstrip()
            print("\t News content should be populated !")
        else:
            news['content'] = 'NA'
            print("\t No Key Match, news content should not be populated !")
        all_news.append(news)
    return all_news
              
             


# https://www.ema.europa.eu
def scrapeEuropa(url):
    cookie_jar=requests.cookies.RequestsCookieJar()
    session=requests.Session()
    header = {'Accept-Encoding': 'gzip, deflate', 'Accept': '/', 'Connection': 'keep-alive',
     "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0"
     }
    print("Utility function for https://www.ema.europa.eu called !")
    bs = getPage(url)
    print("getPage function for https://www.ema.europa.eu called !")
    all_news=[] 
    table = bs.find('div', attrs = {'class':'view-content'})
    for row in table.findAll('a', attrs = {'class':'ecl-link ecl-list-item__link'}):
        news = {}
        news['identifier'] = url
        news['title'] = row.h3.text
        news['url']=row['href']
        news['date'] = row.span.text
        news['keywords'] = ''
        title, url_content, date, content = news['title'].lower(), news['url'], row.span.text ,''
        ret = check_keywords_in_title(title, keywords)
        if ret:
            match = " "
            match = " | ".join(word for word in ret)
            news['keywords'] = match
            print("\t Found a keyword!!")
            url_inner = url + url_content
            bs_inner = getPage(url_inner)
            table_inner = bs_inner.find('div', attrs = {'class':'paragraphs-items paragraphs-items-field-ema-paragraph-content paragraphs-items-field-ema-paragraph-content-full paragraphs-items-full'})
            table_inner_1 = table_inner.find('div', attrs = {'class':'ecl-field__body'})
            table_inner_2 = table_inner_1.findAll('p')
            for i in table_inner_2:
                content += i.get_text()
            news['content'] = content.replace("\n", " ")    
            print("\t News content should be populated !")
        else:
            news['content'] = "NA"
            print("\t No Key Match, news content should not be populated !")
        all_news.append(news)
    return all_news



# https://www.fdanews.com/articles/topic/106?page=5
def scrapeFDA(url):
    cookie_jar=requests.cookies.RequestsCookieJar()
    session=requests.Session()
    header = {'Accept-Encoding': 'gzip, deflate', 'Accept': '/', 'Connection': 'keep-alive',
     "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0"
     }
    print("Utility function for https://www.fdanews.com called !")
    bs = getPage(url)
    print("getPage function for https://www.fdanews.com called !")
    all_news=[]
    # Checkpoint No. of records pulled is incorrect
    table = bs.findAll('article', attrs = {'class':'record article-summary'})
    for row in table:
        news = {}
        news['identifier'], news['title'], news['url'] = url, row.h2.text, row.h2.a['href']
        news['date'] = date_format(row.find('div' , attrs = {'class' : 'date article-summary__post-date'}).text)
        news['keywords'] = ''
        title, url_content, date, content = news['title'].lower(), news['url'], news['date'], ''
        ret = check_keywords_in_title(title, keywords)
        print("check_keywords_in_title called for title:- ", title)
        if ret:
            match = " "
            match = " | ".join(word for word in ret)
            news['keywords'] = match
            print("\t Found a keyword!!")
            url_inner = url_content
            bs_inner = getPage(url_inner)
            table_inner = bs_inner.find('div', attrs = {'body gsd-paywall'})
            table_inner_1 = table_inner.findAll('p', {'class':False, 'id':False, 'align':False})
            for i in table_inner_1:
                content += i.get_text()
            news['content'] = content.replace("\n", " ") 
            print("\t News content should be populated !")
        else:
            news['content'] = "NA"
            print("\t No Key Match, news content should not be populated !")
        all_news.append(news)
    return all_news


# https://www.medtechdive.com/topic/medical-devices/
def scrapeMedTechDive(url):
    cookie_jar=requests.cookies.RequestsCookieJar()
    session=requests.Session()
    header = {'Accept-Encoding': 'gzip, deflate', 'Accept': '/', 'Connection': 'keep-alive',
     "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0"
     }
    print("Utility function for https://www.medtechdive.com/topic/medical-devices/ called !")
    bs = getPage(url)
    print("getPage function for https://www.medtechdive.com/topic/medical-devices/ called !")
    all_news=[] 
    table = bs.find('ul', attrs = {'class':'feed layout-stack-xxl'})
    for row in table.findAll('div', attrs = {'class':'medium-8 columns'}):
        news = {}
        news['identifier'] = url
        news['title'] = row.h3.text.lstrip().rstrip()
        news['url']=row.a['href']
        dummy = row.findAll('span', attrs ={'class':'secondary-label'})[-1]
        dummy = dummy.text.lstrip().rstrip().replace(",", "")
        date = dummy.split(" ")[-3:]
        date = ' '.join(date)
        news['date'] = date_format(date)
        news['keywords'] = ''
        title, url_content, date, content = news['title'].lower(), news['url'], news['date'] ,''
        ret = check_keywords_in_title(title, keywords)
        print("check_keywords_in_title called for title:- ", title)
        if ret:
            match = " "
            match = " | ".join(word for word in ret)
            news['keywords'] = match
            print("\t Found a keyword!!")
            base_url = "https://www.medtechdive.com"
            url_inner = base_url + url_content
            bs_inner = getPage(url_inner)
            table_inner = bs_inner.find('div', attrs = {'class':'large medium article-body'})
            table_inner_1 = table_inner.findAll('p')
            for i in table_inner_1:
                content += i.get_text()
            news['content'] = content.replace("\n", " ") 
            print("\t News content should be populated !")
        else:
            news['content'] = "NA"
            print("\t No Key Match, news content should not be populated !")
        all_news.append(news)
        time.sleep(2)
    return all_news

# https://www.raps.org/news-and-articles/news-articles
def scrapeRaps(url):
    cookie_jar=requests.cookies.RequestsCookieJar()
    session=requests.Session()
    header = {'Accept-Encoding': 'gzip, deflate', 'Accept': '/', 'Connection': 'keep-alive',
     "User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) Gecko/20100101 Firefox/32.0"
     }
    print("Utility function for https://www.raps.org/news-and-articles/news-articles called !")
    req = requests.get(url, headers = header)
    soup=BeautifulSoup(req.content, "html.parser")
    newsList = soup.findAll("div", {"class": "item-content"})
    all_news = []
    for eachNews in newsList:
        news = {}
        news['identifier'] = url
        url_content=eachNews.a['href']
        title = eachNews.a.text.strip().lower()
        date = eachNews.li.text
        date1 = date.split(" ")
        date = date1[1] + " " + date1[0] + " " + date1[2]
        news['title'] = title
        news['url'] = 'https://www.raps.org' + url_content
        news['date'] = date_format(date)
        news['keywords'] = ''
        ret = check_keywords_in_title(title, keywords)
        if ret:
            match = " "
            match = " | ".join(word for word in ret)
            news['keywords'] = match
            print("\t Found a keyword!!")
            req_inner = requests.get(news['url'], headers = header)
            soup_inner = BeautifulSoup(req_inner.content, "html.parser")
            table = soup_inner.find('div', attrs = {'class':'article'})
            row = table.findAll('div')[1]
            news['content'] = row.text
            print("\t News content should be populated !")
        else:
            news['content'] = 'NA'
            print("\t No Key Match, news content should not be populated !")
    
        all_news.append(news)
        time.sleep(2)
    return all_news

def populate(all_news):
    with open(filename, 'a', newline='',  encoding="utf-8") as f:
        w = csv.DictWriter(f,['identifier','title','url','date', 'keywords', 'content'])
        for news in all_news:
            w.writerow(news)
    return 1
filename = 'news_test.csv'
with open(filename, 'a', newline='',  encoding="utf-8") as f:
    w = csv.DictWriter(f,['identifier', 'title','url','date','keywords', 'content'])
    w.writeheader()
    
url = ['https://www.ema.europa.eu',
       'https://www.mddionline.com/regulatory-quality/regulations',
       'https://www.fdanews.com/articles/topic/106?page=5',
       'https://www.medtechdive.com/topic/medical-devices/',
       'https://www.raps.org/news-and-articles/news-articles']


all_news = scrapeEuropa(url[0])
ret = populate(all_news)
if ret == 1:
    print("Data for:-", url[0], " populated successfully !!")

    
all_news = scrape_mddionline(url[1])
ret = populate(all_news)
if ret == 1:
    print("Data for:-", url[1], " populated successfully !!")
    
all_news = scrapeFDA(url[2])
ret = populate(all_news)
if ret == 1:
    print("Data for:-", url[2], " populated successfully !!")

time.sleep(2)

all_news = scrapeMedTechDive(url[3])
ret = populate(all_news)
if ret == 1:
    print("Data for:-", url[3], " populated successfully !!")

all_news = scrapeRaps(url[4])
ret = populate(all_news)
if ret == 1:
    print("Data for:- ", url[4], " populated successfully")
# Out:
# Utility function for https://www.ema.europa.eu called !
# getPage function for https://www.ema.europa.eu called !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 No Key Match, news content should not be populated !
# 	 No Key Match, news content should not be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 No Key Match, news content should not be populated !
# Data for:- https://www.ema.europa.eu  populated successfully !!
# Utility function for https://www.mddionline.com/regulatory-quality/regulations called !
# getPage function for https://www.mddionline.com/regulatory-quality/regulations called !
# 	 Checking for title:  first biopolymer heart valve implanted in humans fares well in study
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  vicentra closes series c funding to expand its insulin pump in europe
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  can non-invasive medical devices help halt liver disease?
# 	 Found a keyword!!
# /general-hospital/can-non-invasive-medical-devices-help-halt-liver-disease
# Keyword foud at:- https://www.mddionline.com/general-hospital/can-non-invasive-medical-devices-help-halt-liver-disease
# 	 News content should be populated !
# 	 Checking for title:  23andme keeps snagging fda nods for cancer marker tests
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  abbott doesn't need m&a to drive revenue ...
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  the reimbursement tide may be turning for irhythm
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  vitalconnect brings in 2022 with $39m financing
# 	 No Key Match, news content should not be populated !
# 	 Checking for title:  j&j dives into medtech’s digital revolution with microsoft collab
# 	 No Key Match, news content should not be populated !
# Data for:- https://www.mddionline.com/regulatory-quality/regulations  populated successfully !!
# Utility function for https://www.fdanews.com called !
# getPage function for https://www.fdanews.com called !
# check_keywords_in_title called for title:-  sd biosensor’s covid-19 at-home test gets fda’s emergency use authorization
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  bioventus receives fda’s 510(k) clearance for its bonescalpel access
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  edwards receives premarket approval for transcatheter valve and prestent
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  lumiradx covid-19 & flu a/b rapid antigen test gains ce mark
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  organox gets premarket approval for its liver perfusion device
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  nextremity solutions gets 510(k) clearance for ankle fusion plating system
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  neuronetics mt cap mental health system cleared
# 	 No Key Match, news content should not be populated !
# Data for:- https://www.fdanews.com/articles/topic/106?page=5  populated successfully !!
# Utility function for https://www.medtechdive.com/topic/medical-devices/ called !
# getPage function for https://www.medtechdive.com/topic/medical-devices/ called !
# check_keywords_in_title called for title:-  edwards seen falling short in q4 based on early us tavr volume data: jefferies
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  irhythm stock jumps nearly 28% after novitas doubles medicare rates for cardiac monitoring
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  hologic tops guidance as covid-19 testing wave delivers another beat
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  medtronic ceo: company on track to hit guidance, omicron impact 'uncertain'
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  abbott targets consumer health, aims to turn diabetes success into wearable growth driver
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  wall street backs stryker-vocera strategic fit but split on valuation
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  fda warning letter cites product safety issues in medtronic diabetes group
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  medtechs brace for hit as hospitals warn of omicron impact on surgeries
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  medtech's biggest deals in 2021 and what to expect next
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  irhythm's medicare pricing saga defined its 2021
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  user growth, product delays and a super bowl ad: diabetes tech heads into 2022 after another eventful year
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  philips: compounds in recalled devices 'not typically' associated with long-term health risks
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  fda seeks feedback on 180-day notice period for termination of covid-19 euas
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  hospitals clamp down on elective surgeries as covid-19 surges
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  cdrh warns review timelines will remain extended in 2022 as pandemic pressures continue
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  most covid-19 medical device euas lack documented supporting data: jama
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  fda warns about log4j cybersecurity vulnerabilities in medical devices
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  at an 'inflection point,' smith & nephew predicts faster growth will follow current challenges
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  j&j device chief on company split, omicron surge, robotic surgery
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  getinge intra-aortic balloon pump recall tied to 1 death, 71 complaints
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  3 medtech markets poised to thrive in 2022 despite renewed covid-19 pressures
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  medtronic's stock price falls nearly 9% following fda warning letter
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  medtronic's covidien initiates ventilator recall due to manufacturing error
# 	 Found a keyword!!
# 	 News content should be populated !
# check_keywords_in_title called for title:-  roundup: baxter completes $10.5b hillrom acquisition
# 	 No Key Match, news content should not be populated !
# check_keywords_in_title called for title:-  neurostimulator to treat stroke fails to gain fda advisory panel support
# 	 No Key Match, news content should not be populated !
# Data for:- https://www.medtechdive.com/topic/medical-devices/  populated successfully !!
# Utility function for https://www.raps.org/news-and-articles/news-articles called !
# 	 No Key Match, news content should not be populated !
# 	 No Key Match, news content should not be populated !
# 	 No Key Match, news content should not be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 No Key Match, news content should not be populated !
# 	 No Key Match, news content should not be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 Found a keyword!!
# 	 News content should be populated !
# 	 No Key Match, news content should not be populated !
# Data for:-  https://www.raps.org/news-and-articles/news-articles  populated successfully
